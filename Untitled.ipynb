# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#!pip install plotly
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import numpy as np
import datetime as dt
from datetime import timedelta

# %%
df = pd.read_csv('confirmed_df.csv')
df.head()
# Out:
#    Unnamed: 0 state      country       Lat       Long  1/22/20  1/23/20  \
# 0           0   NaN  Afghanistan  33.93911  67.709953        0        0
# 1           1   NaN      Albania  41.15330  20.168300        0        0
# 2           2   NaN      Algeria  28.03390   1.659600        0        0
# 3           3   NaN      Andorra  42.50630   1.521800        0        0
# 4           4   NaN       Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  ...  5/15/22  5/16/22  5/17/22  5/18/22  \
# 0        0        0        0  ...   179267   179321   179328   179477
# 1        0        0        0  ...   275615   275621   275688   275732
# 2        0        0        0  ...   265818   265823   265828   265834
# 3        0        0        0  ...    42156    42156    42156    42572
# 4        0        0        0  ...    99287    99287    99287    99287
#
#    5/19/22  5/20/22  5/21/22  5/22/22  5/23/22  5/24/22
# ...

# %%
df[df['location']=='Brazil']
# Out:
#              date location  new_cases  new_deaths  total_cases  total_deaths  \
# 22248  2020-02-26   Brazil        1.0         NaN          1.0           NaN
# 22249  2020-02-27   Brazil        0.0         NaN          1.0           NaN
# 22250  2020-02-28   Brazil        0.0         NaN          1.0           NaN
# 22251  2020-02-29   Brazil        1.0         NaN          2.0           NaN
# 22252  2020-03-01   Brazil        0.0         NaN          2.0           NaN
# ...           ...      ...        ...         ...          ...           ...
# 23047  2022-05-05   Brazil    21682.0       137.0   30524183.0      664131.0
# 23048  2022-05-06   Brazil    19725.0       195.0   30543908.0      664326.0
# 23049  2022-05-07   Brazil    14622.0        35.0   30558530.0      664361.0
# 23050  2022-05-08   Brazil     6006.0        13.0   30564536.0      664374.0
# 23051  2022-05-09   Brazil     9709.0        52.0   30574245.0      664426.0
#
# ...

# %%
brazil = pd.read_csv("flevy.com-coronavirus-brazil.csv")
germany = pd.read_csv("flevy.com-coronavirus-germany.csv")
france = pd.read_csv("flevy.com-coronavirus-france.csv")
india = pd.read_csv("flevy.com-coronavirus-india.csv")
uk = pd.read_csv("flevy.com-coronavirus-united-kingdom.csv")
us = pd.read_csv("flevy.com-coronavirus-united-states.csv")

brazil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Date                            800 non-null    object
#  1   Total Cases                     800 non-null    int64
#  2   New Cases                       800 non-null    int64
#  3   New Cases 7-Day Moving Average  800 non-null    int64
#  4   Case Growth                     800 non-null    object
#  5   Cases Growth 7DMA               800 non-null    object
#  6   Total Deaths                    800 non-null    int64
#  7   New Deaths                      800 non-null    int64
#  8   New Deaths 7DMA                 800 non-null    int64
#  9   Death Growth                    800 non-null    object
#  10  Death Growth 7DMA               800 non-null    object
#  11  Total Recoveries                800 non-null    int64
# ...

# %%
brazil["Date"] = pd.to_datetime(brazil["Date"])
brazil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Date                            800 non-null    datetime64[ns]
#  1   Total Cases                     800 non-null    int64
#  2   New Cases                       800 non-null    int64
#  3   New Cases 7-Day Moving Average  800 non-null    int64
#  4   Case Growth                     800 non-null    object
#  5   Cases Growth 7DMA               800 non-null    object
#  6   Total Deaths                    800 non-null    int64
#  7   New Deaths                      800 non-null    int64
#  8   New Deaths 7DMA                 800 non-null    int64
#  9   Death Growth                    800 non-null    object
#  10  Death Growth 7DMA               800 non-null    object
#  11  Total Recoveries                800 non-null    int64
# ...

# %%
brazil.sort_values(by='Date', inplace=True)

# %%
fig=px.bar(x=brazil["Date"],y=brazil["Total Cases"])
fig.update_layout(title="Distribution of Number of Confirmed Cases",
                  xaxis_title="Date",yaxis_title="Number of Cases")
fig.show()
# Out:
# <div>                            <div id="1f4f8a72-40b8-4ce8-9f7c-6fdece800336" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f4f8a72-40b8-4ce8-9f7c-6fdece800336")) {                    Plotly.newPlot(                        "1f4f8a72-40b8-4ce8-9f7c-6fdece800336",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["2020-02-26T00:00:00", "2020-02-27T00:00:00", "2020-02-28T00:00:00", "2020-02-29T00:00:00", "2020-03-01T00:00:00", "2020-03-02T00:00:00", "2020-03-03T00:00:00", "2020-03-04T00:00:00", "2020-03-05T00:00:00", "2020-03-06T0
# ...

# %%
fig = px.bar(x = brazil["Date"], y = brazil["Total Deaths"])
fig.update_layout(title="Distribution of Number of Deaths",
                  xaxis_title="Date",yaxis_title="Number of Cases")

fig.update_traces(marker_color='red')

fig.show()
# Out:
# <div>                            <div id="d16c79ae-c07f-4ebf-afd8-b17b5252efa4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d16c79ae-c07f-4ebf-afd8-b17b5252efa4")) {                    Plotly.newPlot(                        "d16c79ae-c07f-4ebf-afd8-b17b5252efa4",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "red"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["2020-02-26T00:00:00", "2020-02-27T00:00:00", "2020-02-28T00:00:00", "2020-02-29T00:00:00", "2020-03-01T00:00:00", "2020-03-02T00:00:00", "2020-03-03T00:00:00", "2020-03-04T00:00:00", "2020-03-05T00:00:00", "2020-03-06T00:00
# ...

# %%
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.metrics import mean_squared_error
import pandas as pd
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np
import warnings
warnings.filterwarnings("ignore")
from tqdm import tqdm

# %%
import pmdarima

# %%
brazil
# Out:
#           Date  Total Cases  New Cases  New Cases 7-Day Moving Average  \
# 799 2020-02-26            1          1                               1
# 798 2020-02-27            1          0                               1
# 797 2020-02-28            1          0                               0
# 796 2020-02-29            2          1                               1
# 795 2020-03-01            2          0                               0
# ..         ...          ...        ...                             ...
# 4   2022-05-01     30454499       6263                           15005
# 3   2022-05-02     30460997       6498                           15011
# 2   2022-05-03     30482429      21432                           14910
# 1   2022-05-04     30502501      20072                           14785
# 0   2022-05-05     30524183      21682                           15038
#
#     Case Growth Cases Growth 7DMA  Total Deaths  New Deaths  New Deaths 7DMA  \
# ...

# %%
confirmed_total_date = brazil.groupby(['Date']).agg({'Total Cases':['sum']})
fatalities_total_date = brazil.groupby(['Date']).agg({'Total Deaths':['sum']})
fig, ax = plt.subplots(1, figsize=(17,7))
confirmed_total_date.plot(ax=ax, color='orange')
fatalities_total_date.plot(ax=ax,  color='red')
ax.set_title("Cases and fatalities", size=13)
ax.set_ylabel("Number of cases/fatalities", size=13)
ax.set_xlabel("Date", size=13)
plt.show()

# %%
brazil.set_index('Date')
# Out:
#             Total Cases  New Cases  New Cases 7-Day Moving Average  \
# Date
# 2020-02-26            1          1                               1
# 2020-02-27            1          0                               1
# 2020-02-28            1          0                               0
# 2020-02-29            2          1                               1
# 2020-03-01            2          0                               0
# ...                 ...        ...                             ...
# 2022-05-01     30454499       6263                           15005
# 2022-05-02     30460997       6498                           15011
# 2022-05-03     30482429      21432                           14910
# 2022-05-04     30502501      20072                           14785
# 2022-05-05     30524183      21682                           15038
#
#            Case Growth Cases Growth 7DMA  Total Deaths  New Deaths  \
# Date
# 2020-02-26           0                 0             0           0
# ...

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def ad_test(dataset):
    dftest = adfuller(dataset, autolag = 'AIC')
    print("1. ADF: ", dftest[0])
    print("2. P-Value: ", dftest[1])
    print("3. Num of Lags: ", dftest[2])
    print("4. Num of Observations Used For ADF Regression and Critical Values Calculation: ", dftest[3])
    print("5. Critical Values: ")
    for key, val in dftest[4].items():
        print("\t", key, ": ", val)

# %%
ad_test(brazil["New Cases"])
# Out:
# 1. ADF:  -4.132660192176371
# 2. P-Value:  0.0008548924314811199
# 3. Num of Lags:  21
# 4. Num of Observations Used For ADF Regression and Critical Values Calculation:  778
# 5. Critical Values:
# 	 1% :  -3.438783171038672
# 	 5% :  -2.865262118650577
# 	 10% :  -2.568752018688748

# %%
from pmdarima import auto_arima

warnings.filterwarnings("ignore")

# %%
stepwise_fit = auto_arima(brazil['New Cases'], trace = True, suppress_warnings = True)
stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.15 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=18423.229, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=18376.133, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=18281.950, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=18421.231, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=18226.130, Time=0.29 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=18213.407, Time=0.39 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=18352.863, Time=0.12 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=18177.327, Time=0.31 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=18309.855, Time=0.15 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=18123.768, Time=0.36 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=18240.247, Time=0.18 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=18050.332, Time=0.45 sec
# ...

# %%
print(brazil.shape)

train = brazil.iloc[:-30]
test = brazil.iloc[-30:]

print(train.shape, test.shape)
# Out:
# (800, 20)
# (770, 20) (30, 20)

# %%
import statsmodels.api as st
model = st.tsa.arima.ARIMA(train["New Cases"], order = (5, 1, 2))
model = model.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:              New Cases   No. Observations:                  770
# Model:                 ARIMA(5, 1, 2)   Log Likelihood               -8646.907
# Date:                Sun, 15 May 2022   AIC                          17309.813
# Time:                        17:51:05   BIC                          17346.974
# Sample:                             0   HQIC                         17324.116
#                                 - 770
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3206      0.041      7.896      0.000       0.241       0.400
# ar.L2         -0.5319      0.028    -18.847      0.000      -0.587      -0.477
# ar.L3         -0.3354      0.028    -11.963      0.000      -0.390      -0.280
# ...

# %%
start = len(train)
end = len(train) + len(test) - 1
pred = model.predict(start = start, end = end, type = 'levels')
pred.index = brazil.index[start:end+1]
print(pred)
# Out:
# 29    31124.919868
# 28    32361.406493
# 27    27174.159213
# 26    17869.138651
# 25    11771.974284
# 24    14903.710357
# 23    23336.126668
# 22    30545.511819
# 21    31793.569358
# 20    26490.066799
# 19    18438.041304
# 18    13740.278407
# 17    15792.133428
# 16    22742.492514
# 15    29269.929396
# 14    30687.636083
# 13    26178.081400
# 12    19252.294294
# 11    15068.722666
# 10    16577.358652
# 9     22431.951855
# 8     28175.352399
# 7     29627.315832
# 6     25909.589372
# 5     19948.112162
# 4     16185.954944
# 3     17276.470114
# 2     22220.176569
# 1     27248.819975
# 0     28691.099279
# Name: predicted_mean, dtype: float64

# %%
pred.plot(legend = True)
test['New Cases'].plot(legend = True)
plt.show()

# %%
test['New Cases'].mean()
# Out:
# 16063.7

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(pred, test["New Cases"]))
print(rmse)
# Out:
# 9025.576669587574

# %%
brazil.tail()
# Out:
#         Date  Total Cases  New Cases  New Cases 7-Day Moving Average  \
# 4 2022-05-01     30454499       6263                           15005
# 3 2022-05-02     30460997       6498                           15011
# 2 2022-05-03     30482429      21432                           14910
# 1 2022-05-04     30502501      20072                           14785
# 0 2022-05-05     30524183      21682                           15038
#
#   Case Growth Cases Growth 7DMA  Total Deaths  New Deaths  New Deaths 7DMA  \
# 4       0.02%             0.05%        663752          16              123
# 3       0.02%             0.05%        663838          86              125
# 2       0.07%             0.05%        663930          92              117
# 1       0.07%             0.05%        663994          64               92
# 0       0.07%             0.05%        664131         137               95
#
#   Death Growth Death Growth 7DMA  Total Recoveries  New Recoveries  \
# ...

# %%
pred = model.predict(len(brazil), end = len(brazil) + 30, type = 'levels').rename('ARIMAA')
indexing = pd.date_range(start = '2022-05-05', end = '2022-06-04')
pred.index = indexing

# %%
pred.plot(legend = True)
plt.show()
